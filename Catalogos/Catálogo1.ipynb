# %% [markdown]
# # Preguntas del catálogo

# %% [markdown]
# ## Pregunta #1

# %% [markdown]
# ## Pregunta #2

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Leer la imagen original
A = cv2.imread('imagen1.jpg')
A = cv2.cvtColor(A, cv2.COLOR_BGR2RGB)  # Convertir la imagen de BGR a RGB para mostrar correctamente con Matplotlib

# Mostrar la imagen original
plt.subplot(1, 3, 1)
plt.imshow(A)
plt.title('Imagen original')
plt.axis('off')

# Incorporar ruido sal y pimienta
def add_salt_and_pepper_noise(image, amount):
    noisy = image.copy()
    # Generar ruido
    num_salt = np.ceil(amount * image.size * 0.5)
    num_pepper = np.ceil(amount * image.size * 0.5)
    
    # Añadir sal (pixeles blancos)
    coords = [np.random.randint(0, i - 1, int(num_salt)) for i in image.shape]
    noisy[coords[0], coords[1], :] = 1
    
    # Añadir pimienta (pixeles negros)
    coords = [np.random.randint(0, i - 1, int(num_pepper)) for i in image.shape]
    noisy[coords[0], coords[1], :] = 0
    return noisy

Y = add_salt_and_pepper_noise(A, 0.05)

# Mostrar la imagen con ruido sal y pimienta
plt.subplot(1, 3, 2)
plt.imshow(Y)
plt.title('Imagen con ruido sal y pimienta')
plt.axis('off')

# Eliminar ruido con un filtro de mediana
Z = cv2.medianBlur(Y, 3)

# Mostrar la imagen limpiada
plt.subplot(1, 3, 3)
plt.imshow(Z)
plt.title('Imagen limpiada')
plt.axis('off')

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Leer la imagen original
A = cv2.imread('imagen4.jpg')
A_rgb = cv2.cvtColor(A, cv2.COLOR_BGR2RGB)  # Convertir de BGR a RGB para mostrar correctamente con Matplotlib

# Obtener las dimensiones de la imagen
height, width, channels = A.shape
print(f"Dimensiones: {width}x{height}")
print(f"Número de canales: {channels}")

# Mostrar la imagen original
plt.subplot(1, 2, 1)
plt.imshow(A_rgb)
plt.title('Imagen original')
plt.axis('off')

# Transformación a escala de grises
B = cv2.cvtColor(A, cv2.COLOR_BGR2GRAY)

# Mostrar la imagen en escala de grises
plt.subplot(1, 2, 2)
plt.imshow(B, cmap='gray')
plt.title('Imagen en escala de grises')
plt.axis('off')

plt.show()
# Out:
# Dimensiones: 512x512
# Número de canales: 3

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Leer la imagen original
A = cv2.imread('imagen2.jpg')
A_rgb = cv2.cvtColor(A, cv2.COLOR_BGR2RGB)  # Convertir de BGR a RGB para mostrar correctamente con Matplotlib

# Mostrar la imagen original
plt.subplot(1, 2, 1)
plt.imshow(A_rgb)
plt.title('Imagen original')
plt.axis('off')

# Mejorar el contraste de la imagen usando el método de ecualización de histograma
A_gray = cv2.cvtColor(A, cv2.COLOR_BGR2GRAY)
B = cv2.equalizeHist(A_gray)

# Mostrar la imagen con contraste mejorado
plt.subplot(1, 2, 2)
plt.imshow(B, cmap='gray')
plt.title('Imagen con contraste mejorado')
plt.axis('off')

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Leer la imagen original
A = cv2.imread('imagen1.jpg')
A_rgb = cv2.cvtColor(A, cv2.COLOR_BGR2RGB)  # Convertir de BGR a RGB para mostrar correctamente con Matplotlib

# Mostrar la imagen original
plt.subplot(1, 2, 1)
plt.imshow(A_rgb)
plt.title('Imagen original')
plt.axis('off')

# Redimensionar la imagen al tamaño [256, 256]
B = cv2.resize(A_rgb, (256, 256))

# Mostrar la imagen redimensionada
plt.subplot(1, 2, 2)
plt.imshow(B)
plt.title('Imagen redimensionada')
plt.axis('off')

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Leer la imagen original
A = cv2.imread('imagen1.jpg')
A_rgb = cv2.cvtColor(A, cv2.COLOR_BGR2RGB)  # Convertir de BGR a RGB para mostrar correctamente con Matplotlib

# Mostrar la imagen original
plt.subplot(1, 2, 1)
plt.imshow(A_rgb)
plt.title('Imagen original')
plt.axis('off')

# Redimensionar la imagen al tamaño [256, 256]
B = cv2.resize(A_rgb, (128, 256))

# Mostrar la imagen redimensionada
plt.subplot(1, 2, 2)
plt.imshow(B)
plt.title('Imagen redimensionada')
plt.axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Leer la imagen original
A = cv2.imread('imagen1.jpg')
A_rgb = cv2.cvtColor(A, cv2.COLOR_BGR2RGB)  # Convertir de BGR a RGB para mostrar correctamente con Matplotlib

# Mostrar la imagen original
plt.subplot(1, 2, 1)
plt.imshow(A_rgb)
plt.title('Imagen original')
plt.axis('off')

# Obtener las dimensiones de la imagen
(h, w) = A_rgb.shape[:2]

# Calcular el centro de la imagen
center = (w // 2, h // 2)

# Generar la matriz de transformación para rotar la imagen 45 grados
M = cv2.getRotationMatrix2D(center, 45, 1.0)

# Aplicar la rotación
B = cv2.warpAffine(A_rgb, M, (w, h))

# Mostrar la imagen rotada
plt.subplot(1, 2, 2)
plt.imshow(B)
plt.title('Imagen rotada')
plt.axis('off')

plt.show()

# %%
# !pip install scikit-image
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -andas (/usr/local/lib/python3.10/dist-packages)
# Collecting scikit-image
#   Downloading scikit_image-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.23 in /home/ignacio/.local/lib/python3.10/site-packages (from scikit-image) (1.24.4)
# Requirement already satisfied: scipy>=1.9 in /home/ignacio/.local/lib/python3.10/site-packages (from scikit-image) (1.12.0)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (3.2.1)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (9.5.0)
# Collecting imageio>=2.33 (from scikit-image)
#   Downloading imageio-2.34.2-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Downloading tifffile-2024.8.10-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: packaging>=21 in /home/ignacio/.local/lib/python3.10/site-packages (from scikit-image) (23.2)
# Collecting lazy-loader>=0.4 (from scikit-image)
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Downloading scikit_image-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 13.3 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading imageio-2.34.2-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.5/313.5 kB 17.7 MB/s eta 0:00:00
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading tifffile-2024.8.10-py3-none-any.whl (225 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.8/225.8 kB 11.8 MB/s eta 0:00:00
# WARNING: Ignoring invalid distribution -andas (/usr/local/lib/python3.10/dist-packages)
# Installing collected packages: tifffile, lazy-loader, imageio, scikit-image
# Successfully installed imageio-2.34.2 lazy-loader-0.4 scikit-image-0.24.0 tifffile-2024.8.10
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: /usr/bin/python3 -m pip install --upgrade pip

# %%
import cv2
import matplotlib.pyplot as plt

# Leer la imagen original
A = cv2.imread('imagen3.jpg')
A_rgb = cv2.cvtColor(A, cv2.COLOR_BGR2RGB)  # Convertir de BGR a RGB para mostrar correctamente con Matplotlib

# Mostrar la imagen original
plt.subplot(1, 2, 1)
plt.imshow(A_rgb)
plt.title('Imagen original')
plt.axis('off')

# Convertir la imagen a escala de grises
A_gray = cv2.cvtColor(A, cv2.COLOR_BGR2GRAY)

# Aplicar la detección de bordes usando el algoritmo Canny
B = cv2.Canny(A_gray, 100, 200)

# Mostrar la imagen con bordes resaltados
plt.subplot(1, 2, 2)
plt.imshow(B, cmap='gray')
plt.title('Imagen con bordes resaltados')
plt.axis('off')

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Leer la imagen original
A = cv2.imread('imagen3.jpg')
A_rgb = cv2.cvtColor(A, cv2.COLOR_BGR2RGB)  # Convertir de BGR a RGB para mostrar correctamente con Matplotlib

# Convertir la imagen a escala de grises
A_gray = cv2.cvtColor(A, cv2.COLOR_BGR2GRAY)

# Calcular el umbral automáticamente usando el método de Otsu
_, B = cv2.threshold(A_gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Mostrar la imagen original
plt.subplot(1, 2, 1)
plt.imshow(A_rgb)
plt.title('Imagen original')
plt.axis('off')

# Mostrar la imagen segmentada
plt.subplot(1, 2, 2)
plt.imshow(B, cmap='gray')
plt.title('Imagen segmentada')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Pregunta #3

# %% [markdown]
# ## Pregunta #4
